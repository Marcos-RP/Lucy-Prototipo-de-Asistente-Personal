# %% [markdown]
# # Lectura de los datos iniciales
#
# ---

# %%
# =====================================
# Importación de librerías
# =====================================

import os
import pandas as pd
from glob import glob
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, root_mean_squared_error

# %%
# =====================================
# Importación de datos
# =====================================

df_peliculas = pd.read_csv("../../Fase 1 Datos/Parte 1/Puntuaciones/DatosPeliculasSeries.csv")
df_general = pd.read_csv("../../Fase 1 Datos/Parte 3/Puntuaciones/general.csv")

# %%
# =====================================
# Unificación de puntuaciones
# =====================================

archivos = glob(os.path.join("../../Fase 1 Datos/Parte 2/Puntuaciones", "*.csv"))

matriz = df_general

for archivo in archivos:
    nombre_base = os.path.basename(archivo)
    partes = nombre_base.split(".")
    if len(partes) == 2 and partes[0].isdigit() and partes[1] == "csv":
        archivo = pd.read_csv(archivo)
        matriz = pd.concat([matriz, archivo])

matriz
# Out:
#      userId  Mi Nota        tid
# 0         1        8  tt0114388
# 1         1        2  tt0113627
# 2         1        4  tt0112682
# 3         1       10  tt0115012
# 4         1       10  tt0114746
# ..      ...      ...        ...
# 885  200949        8  tt9603212
# 886  200949        8  tt9619824
# 887  200949        6  tt9760852
# 888  200949        3  tt9764362
# 889  200949        8  tt9777666
#
# [31439089 rows x 3 columns]

# %% [markdown]
# # Selección de usuarios parecidos
#
# ---

# %%
# =====================================
# Unión con usuarios parecidos
# =====================================

nuevo_usuario = {
    "tt0481369": 8,
    "tt0434409": 8
}

df_nuevo = pd.DataFrame(
    list(nuevo_usuario.items()),
    columns=["tid", "nota_nuevo"]
)

df_juntos = matriz.merge(
    df_nuevo,
    on="tid",
    how="right"
)

df_juntos["parecido"] = ((df_juntos["Mi Nota"] - df_juntos["nota_nuevo"]).abs() <= 1.5)

df_juntos
# Out:
#        userId  Mi Nota        tid  nota_nuevo  parecido
# 0          10        7  tt0481369           8      True
# 1          28        6  tt0481369           8     False
# 2          65        4  tt0481369           8     False
# 3          80        6  tt0481369           8     False
# 4         109        5  tt0481369           8     False
# ...       ...      ...        ...         ...       ...
# 38842  200937        9  tt0434409           8      True
# 38843  200943        7  tt0434409           8      True
# 38844  200947        9  tt0434409           8      True
# 38845  200948        5  tt0434409           8     False
# 38846  200949       10  tt0434409           8     False
#
# [38847 rows x 5 columns]

# %%
# =====================================
# Filtrado de usuarios parecidos
# =====================================

similitud = (
    df_juntos
    .groupby("userId")
    .agg(
        coincidencias=("parecido", "sum"),
        comunes=("Mi Nota", lambda x: (x != -1).sum())
    )
)

similitud = similitud[similitud["coincidencias"] >= (similitud["comunes"] * 0.8)]
similitud = similitud[similitud["comunes"] >= (len(nuevo_usuario) * 0.8)]
similitud = similitud.reset_index()

similitud
# Out:
#      userId  coincidencias  comunes
# 0        10              2        2
# 1       204              2        2
# 2       240              2        2
# 3       661              2        2
# 4      1411              2        2
# ..      ...            ...      ...
# 734  199631              2        2
# 735  200213              2        2
# 736  200352              2        2
# 737  200436              2        2
# 738  200933              2        2
#
# [739 rows x 3 columns]

# %%
# =====================================
# Recolección puntuaciones de usuarios parecidos
# =====================================

if similitud.empty:
    final = None

else:
    puntuaciones = similitud.merge(matriz, on="userId", how="left")
    puntuaciones = puntuaciones.groupby("tid", as_index=False)["Mi Nota"].mean()
    puntuaciones["Mi Nota"] = (
        puntuaciones["Mi Nota"]
            .round()
            .clip(1, 10)
            .astype(int)
    )

    puntuaciones_datos = puntuaciones.merge(
        df_peliculas,
        on="tid",
        how="left"
    )

    final = puntuaciones_datos[['tid', 'Tipo', 'Titulo', 'Titulo_ES', 'Año', 'Mi Nota', 'Duracion', 'Generos', 'Puntuacion', 'Num_Votos', 'Actores', 'Directores', 'Idioma']]

final
# Out:
#              tid   Tipo                                     Titulo  \
# 0      tt0000574  movie                The Story of the Kelly Gang
# 1      tt0002130  movie                            Dante's Inferno
# 2      tt0002844  movie  Fantômas: In the Shadow of the Guillotine
# 3      tt0003037  movie                 Fantomas: The Man in Black
# 4      tt0003165  movie          Fantômas: The Dead Man Who Killed
# ...          ...    ...                                        ...
# 31663  tt9902160  movie                                    Herself
# 31664  tt9902160  movie                                    Herself
# 31665  tt9907782  movie                                 The Cursed
# 31666  tt9908390  movie                                    Le lion
# 31667  tt9911196  movie                        The Marriage Escape
#
#                                    Titulo_ES   Año  Mi Nota  Duracion  \
# 0                The Story of the Kelly Gang  1906        7        70
# 1                                El infierno  1911        6        71
# 2      Fantómas a la sombra de la guillotina  1913        7        54
# 3           Fantomas 2: Juve contra Fantomas  1913        7        61
# 4             Fantomas 3: El muerto que mata  1913        7        90
# ...                                      ...   ...      ...       ...
# 31663             Volver a empezar (Herself)  2020        8        97
# 31664                                Herself  2020        8        97
# 31665                             The Cursed  2021        8       111
# 31666                    Una misión de locos  2020        6        95
# 31667                         Demasiado amor  2020        6       103
#
#                           Generos  Puntuacion  Num_Votos  \
# 0      Action,Adventure,Biography         6.0       1039
# 1         Adventure,Drama,Fantasy         7.0       3989
# 2                     Crime,Drama         6.9       2686
# 3                     Crime,Drama         6.9       1826
# 4             Crime,Drama,Mystery         6.9       1455
# ...                           ...         ...        ...
# 31663                       Drama         7.0       5246
# 31664                       Drama         7.0       5246
# 31665      Fantasy,Horror,Mystery         6.2      22054
# 31666                      Comedy         5.5       1600
# 31667                Comedy,Drama         7.4       3520
#
#                                                  Actores  \
# 0      ['Godfrey Cass', 'Bella Cola', 'Will Coyne', '...
# 1      ['Emin Belig Belli', 'Giuseppe de Liguoro', 'E...
# 2      ['André Luguet', 'Georges Melchior', 'Renée Ca...
# 3      ['Georges Melchior', 'Renée Carl', 'Yvette And...
# 4      ['André Luguet', 'Luitz-Morat', 'Georges Melch...
# ...                                                  ...
# 31663  ['Shadaan Felfeli', 'Cathy Belton', 'Art Kearn...
# 31664  ['Shadaan Felfeli', 'Cathy Belton', 'Art Kearn...
# 31665  ['Kelly Reilly', 'Tommy Rodger', 'Amelia Crouc...
# 31666  ['Ophélia Kolb', 'Philippe Duquesne', 'Benoît ...
# 31667  ['Stef Assen', 'Daphne Bunskoek', 'Leonie ter ...
#
#                                               Directores  \
# 0                                       ['Charles Tait']
# 1      ['Giuseppe de Liguoro', 'Adolfo Padovan', 'Fra...
# 2                                    ['Louis Feuillade']
# 3                                    ['Louis Feuillade']
# 4                                    ['Louis Feuillade']
# ...                                                  ...
# 31663                                 ['Phyllida Lloyd']
# 31664                                 ['Phyllida Lloyd']
# 31665                                     ['Sean Ellis']
# 31666                         ['Ludovic Colbeau-Justin']
# 31667                                ['Johan Nijenhuis']
#
#                                                 Idioma
# 0                                          [nan, 'en']
# 1                              ['ja', 'en', nan, 'sv']
# 2                        ['sv', 'ja', 'tr', nan, 'en']
# 3                                    ['sv', nan, 'en']
# 4                                          [nan, 'sv']
# ...                                                ...
# 31663              ['he', 'ca', 'ja', 'fr', nan, 'en']
# 31664              ['he', 'ca', 'ja', 'fr', nan, 'en']
# 31665  ['hi', 'bg', 'tr', 'ja', 'fr', nan, 'es', 'en']
# 31666                    ['tr', 'ja', 'fr', nan, 'en']
# 31667                               ['yue', nan, 'en']
#
# [31668 rows x 13 columns]

# %% [markdown]
# # Predicción
#
# ---

# %%
final["Mi Nota"].value_counts().sort_index()
# Out:
# Mi Nota
# 1      562
# 2      514
# 3      548
# 4     1814
# 5     2981
# 6     8080
# 7     9571
# 8     6258
# 9      889
# 10     451
# Name: count, dtype: int64

# %%
# =====================================
# Balanceo de clases
# =====================================

conteo = int((final["Mi Nota"].value_counts().min()) * 1.5)

def eleccion_clases(df, conteo):
    n = len(df)
    if n > conteo:
        return df.sample(n=conteo, random_state=100496072)
    else:
        return df

df_balanceado = (
    final
    .groupby("Mi Nota", group_keys=False)
    .apply(eleccion_clases, conteo)
)

df_balanceado
# Out:
# C:\Users\romom\AppData\Local\Temp\ipykernel_17696\4246157893.py:17: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(eleccion_clases, conteo)
#              tid   Tipo                                             Titulo  \
# 28     tt0010726  movie            The Spiders - Episode 1: The Golden Sea
# 29     tt0010726  movie            The Spiders - Episode 1: The Golden Sea
# 125    tt0018806  movie                                          The Crowd
# 175    tt0021890  movie                                     The Front Page
# 176    tt0021890  movie                                     The Front Page
# ...          ...    ...                                                ...
# 31419  tt9239552  movie  Konosuba!: God's Blessing on This Wonderful Wo...
# 31428  tt9252468  movie                                              Mosul
# 31588  tt9707456  movie                                         Nightshade
# 31622  tt9794630  movie                                       The Vanished
# 31623  tt9794630  movie                                       The Vanished
#
#                                                Titulo_ES   Año  Mi Nota  \
# 28                          Las arañas 1: El lago de oro  1919        1
# 29                                                Arañas  1919        1
# 125                                    Y el mundo marcha  1928        1
# 175                                        Primera plana  1931        1
# 176                                    Un gran reportaje  1931        1
# ...                                                  ...   ...      ...
# 31419  Eiga Kono subarashii sekai ni shukufuku o!: Ku...  2019       10
# 31428                                              Mosul  2019       10
# 31588                                         Nightshade  2022       10
# 31622                                       Sense rastre  2020       10
# 31623                                         Sin rastro  2020       10
#
#        Duracion                     Generos  Puntuacion  Num_Votos  \
# 28          130     Adventure,Drama,Western         6.5       1597
# 29          130     Adventure,Drama,Western         6.5       1597
# 125          98               Drama,Romance         8.0       9873
# 175         101          Comedy,Crime,Drama         6.7       3776
# 176         101          Comedy,Crime,Drama         6.7       3776
# ...         ...                         ...         ...        ...
# 31419        90  Action,Adventure,Animation         7.8       6707
# 31428       101       Action,Drama,Thriller         7.1      32567
# 31588        90        Crime,Fantasy,Horror         4.0        370
# 31622       115       Action,Crime,Thriller         5.7      12991
# 31623       115       Action,Crime,Thriller         5.7      12991
#
#                                                  Actores  \
# 28     ['Friedrich Kühne', 'Lil Dagover', 'Ressel Orl...
# 29     ['Friedrich Kühne', 'Lil Dagover', 'Ressel Orl...
# 125    ['Bert Roach', 'Daniel G. Tomlinson', 'John D....
# 175    ['Adolphe Menjou', 'Matt Moore', 'Mary Brian',...
# 176    ['Adolphe Menjou', 'Matt Moore', 'Mary Brian',...
# ...                                                  ...
# 31419  ['Yui Horie', 'Rie Takahashi', 'Aki Toyosaki',...
# 31428  ['Tarik Rmili', 'Thaer Al-Shayei', "Is'haq Eli...
# 31588  ['Jason Patric', 'Dina Meyer', 'Jaime Gallaghe...
# 31622  ['Kk Heim', 'Jason Patric', 'Mitchell L. Johns...
# 31623  ['Kk Heim', 'Jason Patric', 'Mitchell L. Johns...
#
#                          Directores  \
# 28                   ['Fritz Lang']
# 29                   ['Fritz Lang']
# 125                  ['King Vidor']
# 175             ['Lewis Milestone']
# 176             ['Lewis Milestone']
# ...                             ...
# 31419          ['Takaomi Kanasaki']
# 31428  ['Matthew Michael Carnahan']
# 31588           ['Landon Williams']
# 31622           ['Peter Facinelli']
# 31623           ['Peter Facinelli']
#
#                                                 Idioma
# 28                                         [nan, 'bg']
# 29                                         [nan, 'bg']
# 125    ['bg', 'ru', 'ja', 'tr', 'fr', nan, 'sr', 'en']
# 175                ['ru', 'ca', 'ja', 'fr', nan, 'en']
# 176                ['ru', 'ca', 'ja', 'fr', nan, 'en']
# ...                                                ...
# 31419                                ['ja', nan, 'en']
# 31428       ['hi', 'cmn', 'ja', 'tr', 'fr', nan, 'en']
# 31588                          ['tr', 'hi', nan, 'en']
# 31622              ['tr', 'ca', 'ja', 'fr', nan, 'en']
# 31623              ['tr', 'ca', 'ja', 'fr', nan, 'en']
#
# [6131 rows x 13 columns]

# %%
# =====================================
# Entrenamiento del modelo para las predicciones
# =====================================

df_datos_reg = df_balanceado[['Tipo', 'Año', 'Duracion', 'Puntuacion', 'Num_Votos', 'Generos', 'Mi Nota']].copy()
dummies = df_datos_reg["Generos"].str.get_dummies(sep=",")
dummies2 = df_datos_reg["Tipo"].str.get_dummies(sep=",")
df_datos_reg = df_datos_reg.join(dummies2).drop(columns=["Tipo"])
df_datos_reg = df_datos_reg.join(dummies).drop(columns=["Generos"])
df_datos_reg['Mi Nota'] /= 10


col_gen = ['Año', 'Duracion', 'Puntuacion', 'Num_Votos', 'Mi Nota', 'movie', 'tvSeries', 'tvMiniSeries',
           'tvSpecial', 'Thriller', 'Horror', 'Documentary', 'Sci-Fi','Romance', 'Drama', 'Sport', 'War', 'Biography',
           'Musical', 'Crime', 'Music', 'Action', 'Short', 'History', 'Comedy', 'Mystery', 'Animation', 'Adventure',
           'Family', 'Fantasy', 'Game-Show', 'Adult', 'Western', 'Talk-Show','Film-Noir']

for col in col_gen:
    if col not in df_datos_reg.columns:
        df_datos_reg[col] = 0

df_datos_reg = df_datos_reg[col_gen]

X_reg = df_datos_reg.drop("Mi Nota", axis=1)
y_reg = df_datos_reg["Mi Nota"]


modelo = Pipeline([
    ('scaler', RobustScaler()),
    ('modelo', RandomForestRegressor(min_samples_leaf=2, min_samples_split=5, random_state=100496072))
])

modelo.fit(X_reg, y_reg)
y_pred_completo_reg = modelo.predict(X_reg)
rmse_rf_reg = root_mean_squared_error(y_reg, y_pred_completo_reg)

print("\nRMSE:", rmse_rf_reg)
print("R2:", r2_score(y_reg, y_pred_completo_reg))
# Out:
# RMSE: 0.11552140856989553
# R2: 0.8225031748431688

# %%
# =====================================
# Realización de predicción
# =====================================

avatar = "tt0499549"
informacion = df_peliculas[(df_peliculas["tid"] == avatar)]

a_predecir = informacion[['Tipo', 'Año', 'Duracion', 'Puntuacion', 'Num_Votos', 'Generos']].copy()

dummies = a_predecir["Generos"].str.get_dummies(sep=",")
dummies2 = a_predecir["Tipo"].str.get_dummies(sep=",")
a_predecir = a_predecir.join(dummies2).drop(columns=["Tipo"])
a_predecir = a_predecir.join(dummies).drop(columns=["Generos"])

a_predecir = pd.DataFrame(a_predecir)

col_gen = ['Año', 'Duracion', 'Puntuacion', 'Num_Votos', 'movie', 'tvSeries', 'tvMiniSeries',
           'tvSpecial', 'Thriller', 'Horror', 'Documentary', 'Sci-Fi', 'Romance', 'Drama', 'Sport', 'War', 'Biography',
           'Musical', 'Crime', 'Music', 'Action', 'Short', 'History', 'Comedy', 'Mystery', 'Animation', 'Adventure',
           'Family', 'Fantasy', 'Game-Show', 'Adult', 'Western', 'Talk-Show', 'Film-Noir']

missing = [c for c in col_gen if c not in a_predecir.columns]
if missing:
    for c in missing:
        a_predecir[c] = 0

a_predecir = a_predecir[col_gen]

prediccion = modelo.predict(a_predecir)
print(f"La probabilidad de le guste es de un {int(prediccion[0] * 100)}%")
# Out:
# La probabilidad de le guste es de un 70%

# %% [markdown]
# # Recomendación
#
# ---

# %%
# =====================================
# Realización de recomendaciones
# =====================================

recomendacion = []

if final is not None:

    recomendacion = final.merge(df_nuevo["tid"], on="tid", how='left', indicator=True)
    recomendacion = recomendacion[recomendacion['_merge'] == 'left_only'].drop(columns=['_merge'])
    recomendacion = recomendacion[recomendacion['Mi Nota'] >= 7.5]


if len(recomendacion) == 0:
    print("Personal")
    nuevo_df_filtrado = df_nuevo[df_nuevo["nota_nuevo"] > 7.5]

    tipos = nuevo_df_filtrado["Tipo"].value_counts().index.tolist()

    tipo1 = tipos[0]
    tipo2 = tipos[1] if len(tipos) > 1 else tipo1

    tipos = "|".join([tipo1, tipo2])

    conteo_anos_5 = nuevo_df_filtrado["Año"].value_counts().head(5).index.tolist()

    ano_minimo = min(conteo_anos_5)
    ano_maximo = max(conteo_anos_5) + 5
    puntuacion_minima = nuevo_df_filtrado["Puntuacion"].min()

    conteo_generos = (
        nuevo_df_filtrado["Generos"]
        .str.split(",")
        .explode()
        .str.strip()
        .value_counts()
    )

    rows, columns = nuevo_df_filtrado.shape

    generos_mas15 = conteo_generos[conteo_generos > (rows * 0.15)]

    sigeneross = generos_mas15.index.tolist()
    sigeneros = "|".join(sigeneross)

    nogeneross = ["None"]
    nogeneros = "|".join(nogeneross)

    recomendacion = df_peliculas[
        (df_peliculas.Tipo.str.contains(tipos)) &
        (df_peliculas.Año >= ano_minimo) &
        (df_peliculas.Año <= ano_maximo) &
        (df_peliculas.Puntuacion >= puntuacion_minima) &
        (df_peliculas.Generos.str.contains(sigeneros, case=False, na=False)) &
        (~df_peliculas.Generos.str.contains(nogeneros, case=False, na=False))
    ]

    recomendacion = recomendacion.merge(nuevo_df_filtrado["tid"], on="tid", how='left', indicator=True)
    recomendacion = recomendacion[recomendacion['_merge'] == 'left_only'].drop(columns=['_merge'])

recomendacion = recomendacion.sort_values(["Num_Votos", "Puntuacion"], ascending=False)
recomendacion.head(100)
# Out:
#              tid   Tipo                    Titulo            Titulo_ES   Año  \
# 10029  tt0111161  movie  The Shawshank Redemption      Cadena perpetua  1994
# 10030  tt0111161  movie  The Shawshank Redemption      Cadena perpètua  1994
# 17462  tt0468569  movie           The Dark Knight  El caballero oscuro  2008
# 17463  tt0468569  movie           The Dark Knight     El cavaller fosc  2008
# 21773  tt1375666  movie                 Inception               Origen  2010
# ...          ...    ...                       ...                  ...   ...
# 19581  tt1049413  movie                        Up                   Up  2009
# 5579   tt0081505  movie               The Shining        El resplandor  1980
# 5580   tt0081505  movie               The Shining        La resplendor  1980
# 15669  tt0371746  movie                  Iron Man             Iron Man  2008
# 15670  tt0371746  movie                  Iron Man             Iron Man  2008
#
#        Mi Nota  Duracion                     Generos  Puntuacion  Num_Votos  \
# 10029        9       142                       Drama         9.3    3128869
# 10030        9       142                       Drama         9.3    3128869
# 17462        9       152          Action,Crime,Drama         9.1    3104589
# 17463        9       152          Action,Crime,Drama         9.1    3104589
# 21773        9       148     Action,Adventure,Sci-Fi         8.8    2758879
# ...        ...       ...                         ...         ...        ...
# 19581        8        96  Adventure,Animation,Comedy         8.3    1211924
# 5579         8       146                Drama,Horror         8.4    1201169
# 5580         8       146                Drama,Horror         8.4    1201169
# 15669        8       126     Action,Adventure,Sci-Fi         7.9    1201008
# 15670        8       126     Action,Adventure,Sci-Fi         7.9    1201008
#
#                                                  Actores  \
# 10029  ['Larry Brandenburg', 'Jeffrey DeMunn', 'Mark ...
# 10030  ['Larry Brandenburg', 'Jeffrey DeMunn', 'Mark ...
# 17462  ['Gary Oldman', 'Cillian Murphy', 'Maggie Gyll...
# 17463  ['Gary Oldman', 'Cillian Murphy', 'Maggie Gyll...
# 21773  ['Tom Berenger', 'Joseph Gordon-Levitt', 'Pete...
# ...                                                  ...
# 19581  ['David Kaye', 'Elie Docter', 'Jeremy Leary', ...
# 5579   ['Tony Burton', 'Lia Beldam', 'Jack Nicholson'...
# 5580   ['Tony Burton', 'Lia Beldam', 'Jack Nicholson'...
# 15669  ['Sayed Badreya', 'Faran Tahir', 'Bill Smitrov...
# 15670  ['Sayed Badreya', 'Faran Tahir', 'Bill Smitrov...
#
#                             Directores  \
# 10029               ['Frank Darabont']
# 10030               ['Frank Darabont']
# 17462            ['Christopher Nolan']
# 17463            ['Christopher Nolan']
# 21773            ['Christopher Nolan']
# ...                                ...
# 19581  ['Bob Peterson', 'Pete Docter']
# 5579               ['Stanley Kubrick']
# 5580               ['Stanley Kubrick']
# 15669                  ['Jon Favreau']
# 15670                  ['Jon Favreau']
#
#                                                   Idioma
# 10029  ['hi', 'bg', 'he', 'cmn', 'sv', 'th', 'ru', 'y...
# 10030  ['hi', 'bg', 'he', 'cmn', 'sv', 'th', 'ru', 'y...
# 17462  ['hi', 'bg', 'cmn', 'ta', 'th', 'ru', 'yue', '...
# 17463  ['hi', 'bg', 'cmn', 'ta', 'th', 'ru', 'yue', '...
# 21773  ['hi', 'bg', 'he', 'cmn', 'th', 'ta', 'ru', 'y...
# ...                                                  ...
# 19581  ['hi', 'bg', 'cmn', 'th', 'ru', 'yue', 'ca', '...
# 5579   ['hi', 'bg', 'he', 'cmn', 'th', 'ru', 'yue', '...
# 5580   ['hi', 'bg', 'he', 'cmn', 'th', 'ru', 'yue', '...
# 15669  ['hi', 'bg', 'cmn', 'ru', 'yue', 'ca', 'ja', '...
# 15670  ['hi', 'bg', 'cmn', 'ru', 'yue', 'ca', 'ja', '...
#
# [100 rows x 13 columns]
